# %%
import pandas as pd

# %%
file = pd.read_excel(open('dataset_artificial.xlsx', 'rb'))
X = pd.DataFrame(file, columns=(['x', 'y']))

# %%
X
# Out:
#          x      y
# 0     1.00   6.00
# 1     1.90    NaN
# 2     1.90   3.20
# 3     2.00   4.50
# 4      NaN   2.10
# 5     2.80   4.00
# 6     2.75   6.05
# 7     3.00    NaN
# 8     3.50  28.20
# 9     3.90   2.95
# 10     NaN   7.60
# 11    4.05   4.95
# 12    4.20   5.80
# 13    4.50  27.00
# 14    5.00   6.00
# 15    5.00   9.10
# 16    5.00  29.40
# 17    5.10   2.00
# 18    5.10   4.00
# 19    5.10  26.00
# 20    5.90   4.85
# 21    6.00   3.00
# 22    6.10   6.95
# 23    6.10  26.20
# 24    6.10  28.20
# 25    6.85  31.00
# 26    7.10   5.95
# 27    7.20   3.95
# 28    7.20   5.00
# 29    7.50  29.00
# 30    7.50  30.00
# 31    7.50   2.20
# 32    7.90  25.50
# 33    8.20  28.00
# 34    8.90   3.90
# 35    8.95   6.20
# 36    9.00  26.10
# 37    9.20  30.20
# 38    9.90  31.85
# 39    9.95  25.00
# 40   10.00  27.50
# 41   10.00  28.20
# 42   10.20  29.80
# 43   11.45  26.00
# 44   11.50  27.10
# 45   11.80  30.50
# 46   12.00  25.00
# 47   13.95  28.00
# 48   14.20  32.20
# ...

# %%
pd.options.display.min_rows = 890

# %%
pd.options.display.max_rows = 890

# %%
X.dtypes
# Out:
# x    float64
# y    float64
# dtype: object

# %%
X.isna().sum()
# Out:
# x    2
# y    2
# dtype: int64

# %%
X.hist()
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'y'}>]], dtype=object)

# %%
x_hilang = X['x'].isna().mean()*100
print('Presentase Data Yang Hilang: {: .2f}% '.format(x_hilang))
# Out:
# Presentase Data Yang Hilang:  1.79%

# %%
X['x'] = X['x'].fillna(method='pad')

# %%
X.isna().sum()
# Out:
# x    0
# y    2
# dtype: int64

# %%
X
# Out:
#          x      y
# 0     1.00   6.00
# 1     1.90    NaN
# 2     1.90   3.20
# 3     2.00   4.50
# 4     2.00   2.10
# 5     2.80   4.00
# 6     2.75   6.05
# 7     3.00    NaN
# 8     3.50  28.20
# 9     3.90   2.95
# 10    3.90   7.60
# 11    4.05   4.95
# 12    4.20   5.80
# 13    4.50  27.00
# 14    5.00   6.00
# 15    5.00   9.10
# 16    5.00  29.40
# 17    5.10   2.00
# 18    5.10   4.00
# 19    5.10  26.00
# 20    5.90   4.85
# 21    6.00   3.00
# 22    6.10   6.95
# 23    6.10  26.20
# 24    6.10  28.20
# 25    6.85  31.00
# 26    7.10   5.95
# 27    7.20   3.95
# 28    7.20   5.00
# 29    7.50  29.00
# 30    7.50  30.00
# 31    7.50   2.20
# 32    7.90  25.50
# 33    8.20  28.00
# 34    8.90   3.90
# 35    8.95   6.20
# 36    9.00  26.10
# 37    9.20  30.20
# 38    9.90  31.85
# 39    9.95  25.00
# 40   10.00  27.50
# 41   10.00  28.20
# 42   10.20  29.80
# 43   11.45  26.00
# 44   11.50  27.10
# 45   11.80  30.50
# 46   12.00  25.00
# 47   13.95  28.00
# 48   14.20  32.20
# ...

# %%
X.to_excel('Coba.xlsx')
